# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswikumar770/pw_data-sci/blob/main/matplotlib_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Ans- Matplotlib is a data visualization library in Python used to create a wide variety of plots. Five common plot types from the Pyplot module:
#
#   1.	Line plot
#   2.	Scatter plot
#   3.	Bar plot
#   4.	Histogram
#   5.	Box plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y.
# Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Ans-- A scatter plot is a diagram where each value in the data set is represented by a dot

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Plot scatter plot
plt.scatter(x, y, color='g', alpha=0.6)
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# Ans- subplot() function can be used to create a figure with multiple subplots.

# %%
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.plot(x1, y1, color='r')
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x2, y2,  color='g')
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x3, y3,  color='b')
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x4, y4,  color='purple')
plt.title('Line Plot 4')

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans- A bar plot is a graphical representation of data using rectangular bars, where the length of each bar corresponds to the value it represents. The bars can be plotted either vertically or horizontally. Bar plots are primarily used to:
# 1. Compare categories
# 2. Show trends
# 3. Visualize frequencies
# 4. Highlight differences

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical bar plot
plt.bar(company, profit)
plt.title('Profit by Company')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# Horizontal bar plot
plt.barh(company, profit, color='y')
plt.title('Profit by Company')
plt.xlabel('Profit ')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans- A box plot is a standardized way of displaying the distribution of data based on five summary statistics:
#
# 1. Minimum
# 2. First quartile
# 3. Median
# 4. Third quartile
# 5. Maximum
#
# Box plots are used for the following purposes:
#
# 1. Visualizing the distribution of data
# 2. Comparing distributions
# 3. Identifying outliers
# 4. Summarizing data succinctly

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.title('Box Plot Example')
plt.ylabel('Values')
plt.show()
# Out:
# <ipython-input-18-491b25b733e6>:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
